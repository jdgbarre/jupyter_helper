# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# ## EDA functions

# %% [markdown]
# Secondary functions

# %%
import pandas as pd

# ---------------------------------------------------------

# Display a pandas dataframe format using print()
pd.options.display.float_format = '{:,.3f}'.format

# ---------------------------------------------------------

""" 
Function to highlight rows based on data type
"""
def dtype_highlight(x):
    if x['type'] == 'object':
        color = '#2b83ba'
    elif (x['type'] == 'int64') | (x['type'] == 'int32'):
        color = '#abdda4'
    elif (x['type'] == 'float64') | (x['type'] == 'float32'):
        color = '#ffffbf'
    elif x['type'] == 'datetime64[ns]':
        color = '#fdae61'
    else:
        color = ''
        
    return ['background-color : {}'.format(color) for val in x]

""" 
Function to highlight rows based on data type
"""
def highlight_row_unique(x):
    if x.name == 'unique':
        color = 'mediumpurple'
    else:
        color = ''
    return ['background-color: {}'.format(color) for val in x]

"""
Color zero values in red
"""
def color_zero_red(val):
    """
    Takes a scalar and returns a string with
    the css property `'background-color: red'` for negative
    strings, black otherwise.
    """
    color = 'indianred' if val <= 0 else ' '
    return 'background-color: %s' % color

"""
Color zero values in green
"""
def color_zero_green(val):
    """
    Takes a scalar and returns a string with
    the css property `'background-color: green'` for negative
    strings, black otherwise.
    """
    color = 'lightgreen' if val == 0 else ' '
    return 'background-color: %s' % color

# ---------------------------------------------------------

# %% [markdown]
# ## Principal functions. They all start with the word 'fun'.

# %%
# ---------------------------------------------------------

"""
Create table with types of DataFrame
"""
def fun_df_types(df):
    df_dtypes = pd.DataFrame(df.dtypes.reset_index())    
    df_dtypes.columns = ['column', 'type']
    
    return df_dtypes.style.apply(dtype_highlight, axis=1)

"""
Return non-numeric columns summary
"""
def fun_non_numeric_summary(df):
    try:
        desc = df.describe(include=['O'])
        return desc.style.apply(highlight_row_unique, axis =1)
    except ValueError:
        print("Oops! There aren't variables of object type")

"""
Return numeric columns summary
"""
def fun_numeric_summary(df):
    try:
        desc = df.describe(exclude='object') \
            .sort_values('mean', axis = 1)
        return desc.style.applymap(color_zero_red)
    except ValueError:
        print("Oops! There aren't variables of numeric type")

"""
Return how many missing values in each column
"""
def fun_missing_value(df):
    missing = df.isnull().sum()
    df_missing = pd.DataFrame(
        missing.to_frame().reset_index(), columns=['index',0]
                             )
    df_missing.columns = ['column','missing_number']
    df_missing['pct_missing'] = 100 * df_missing['missing_number'] / df.shape[0]
    
    return df_missing.sort_values(by=['pct_missing'], ascending =False) \
                    .style.applymap(color_zero_green)

"""
Return rows with any NaN value
"""
def fun_any_missing_row(df):

    return df[df.isnull().any(axis = 1)]

"""
Return frequency for each dataframe column
"""
def fun_freq_column(column):
    ct = pd.crosstab(index=column, columns="ptc_frequency") \
           .sort_values('ptc_frequency', ascending=False)
    
    return ct / (ct.sum()/100)

# ---------------------------------------------------------

# %% [markdown]
# ## Examples to use EDA functions

# %%
from sklearn.datasets import load_iris

def change(number):
    try:
        return iris.target_names[number]
    except IndexError:
        return "error"

    # loading data
df_iris = pd.DataFrame(load_iris().data, columns = load_iris().feature_names)
iris = load_iris()
iris_target = pd.DataFrame(iris.target, columns=['target']).applymap(change)

# %%
# Dataframe types
fun_df_types(df_iris)
# Out:
# <style  type="text/css" >
#     #T_64e09858_5e63_11e8_95ec_6c4008b1f526row0_col0 {
#             background-color :  #ffffbf;
#         }    #T_64e09858_5e63_11e8_95ec_6c4008b1f526row0_col1 {
#             background-color :  #ffffbf;
#         }    #T_64e09858_5e63_11e8_95ec_6c4008b1f526row1_col0 {
#             background-color :  #ffffbf;
#         }    #T_64e09858_5e63_11e8_95ec_6c4008b1f526row1_col1 {
#             background-color :  #ffffbf;
#         }    #T_64e09858_5e63_11e8_95ec_6c4008b1f526row2_col0 {
#             background-color :  #ffffbf;
#         }    #T_64e09858_5e63_11e8_95ec_6c4008b1f526row2_col1 {
#             background-color :  #ffffbf;
#         }    #T_64e09858_5e63_11e8_95ec_6c4008b1f526row3_col0 {
#             background-color :  #ffffbf;
#         }    #T_64e09858_5e63_11e8_95ec_6c4008b1f526row3_col1 {
#             background-color :  #ffffbf;
#         }</style>
# <table id="T_64e09858_5e63_11e8_95ec_6c4008b1f526" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >column</th>
#         <th class="col_heading level0 col1" >type</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_64e09858_5e63_11e8_95ec_6c4008b1f526level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_64e09858_5e63_11e8_95ec_6c4008b1f526row0_col0" class="data row0 col0" >sepal length (cm)</td>
#         <td id="T_64e09858_5e63_11e8_95ec_6c4008b1f526row0_col1" class="data row0 col1" >float64</td>
#     </tr>    <tr>
#         <th id="T_64e09858_5e63_11e8_95ec_6c4008b1f526level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_64e09858_5e63_11e8_95ec_6c4008b1f526row1_col0" class="data row1 col0" >sepal width (cm)</td>
#         <td id="T_64e09858_5e63_11e8_95ec_6c4008b1f526row1_col1" class="data row1 col1" >float64</td>
#     </tr>    <tr>
#         <th id="T_64e09858_5e63_11e8_95ec_6c4008b1f526level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_64e09858_5e63_11e8_95ec_6c4008b1f526row2_col0" class="data row2 col0" >petal length (cm)</td>
#         <td id="T_64e09858_5e63_11e8_95ec_6c4008b1f526row2_col1" class="data row2 col1" >float64</td>
#     </tr>    <tr>
#         <th id="T_64e09858_5e63_11e8_95ec_6c4008b1f526level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_64e09858_5e63_11e8_95ec_6c4008b1f526row3_col0" class="data row3 col0" >petal width (cm)</td>
#         <td id="T_64e09858_5e63_11e8_95ec_6c4008b1f526row3_col1" class="data row3 col1" >float64</td>
#     </tr></tbody>
# </table>

# %%
# Non-Numeric columns summary
fun_non_numeric_summary(df_iris)
# Out:
# Oops! There aren't variables of object type

# %%
# Numeric columns summary
fun_numeric_summary(df_iris)
# Out:
# <style  type="text/css" >
#     #T_6571cbde_5e63_11e8_94ed_6c4008b1f526row0_col0 {
#             background-color:   ;
#         }    #T_6571cbde_5e63_11e8_94ed_6c4008b1f526row0_col1 {
#             background-color:   ;
#         }    #T_6571cbde_5e63_11e8_94ed_6c4008b1f526row0_col2 {
#             background-color:   ;
#         }    #T_6571cbde_5e63_11e8_94ed_6c4008b1f526row0_col3 {
#             background-color:   ;
#         }    #T_6571cbde_5e63_11e8_94ed_6c4008b1f526row1_col0 {
#             background-color:   ;
#         }    #T_6571cbde_5e63_11e8_94ed_6c4008b1f526row1_col1 {
#             background-color:   ;
#         }    #T_6571cbde_5e63_11e8_94ed_6c4008b1f526row1_col2 {
#             background-color:   ;
#         }    #T_6571cbde_5e63_11e8_94ed_6c4008b1f526row1_col3 {
#             background-color:   ;
#         }    #T_6571cbde_5e63_11e8_94ed_6c4008b1f526row2_col0 {
#             background-color:   ;
#         }    #T_6571cbde_5e63_11e8_94ed_6c4008b1f526row2_col1 {
#             background-color:   ;
#         }    #T_6571cbde_5e63_11e8_94ed_6c4008b1f526row2_col2 {
#             background-color:   ;
#         }    #T_6571cbde_5e63_11e8_94ed_6c4008b1f526row2_col3 {
#             background-color:   ;
#         }    #T_6571cbde_5e63_11e8_94ed_6c4008b1f526row3_col0 {
#             background-color:   ;
#         }    #T_6571cbde_5e63_11e8_94ed_6c4008b1f526row3_col1 {
#             background-color:   ;
#         }    #T_6571cbde_5e63_11e8_94ed_6c4008b1f526row3_col2 {
#             background-color:   ;
#         }    #T_6571cbde_5e63_11e8_94ed_6c4008b1f526row3_col3 {
#             background-color:   ;
#         }    #T_6571cbde_5e63_11e8_94ed_6c4008b1f526row4_col0 {
#             background-color:   ;
#         }    #T_6571cbde_5e63_11e8_94ed_6c4008b1f526row4_col1 {
#             background-color:   ;
#         }    #T_6571cbde_5e63_11e8_94ed_6c4008b1f526row4_col2 {
#             background-color:   ;
#         }    #T_6571cbde_5e63_11e8_94ed_6c4008b1f526row4_col3 {
#             background-color:   ;
#         }    #T_6571cbde_5e63_11e8_94ed_6c4008b1f526row5_col0 {
#             background-color:   ;
#         }    #T_6571cbde_5e63_11e8_94ed_6c4008b1f526row5_col1 {
#             background-color:   ;
#         }    #T_6571cbde_5e63_11e8_94ed_6c4008b1f526row5_col2 {
#             background-color:   ;
#         }    #T_6571cbde_5e63_11e8_94ed_6c4008b1f526row5_col3 {
#             background-color:   ;
#         }    #T_6571cbde_5e63_11e8_94ed_6c4008b1f526row6_col0 {
#             background-color:   ;
#         }    #T_6571cbde_5e63_11e8_94ed_6c4008b1f526row6_col1 {
#             background-color:   ;
#         }    #T_6571cbde_5e63_11e8_94ed_6c4008b1f526row6_col2 {
#             background-color:   ;
#         }    #T_6571cbde_5e63_11e8_94ed_6c4008b1f526row6_col3 {
#             background-color:   ;
#         }    #T_6571cbde_5e63_11e8_94ed_6c4008b1f526row7_col0 {
#             background-color:   ;
#         }    #T_6571cbde_5e63_11e8_94ed_6c4008b1f526row7_col1 {
#             background-color:   ;
#         }    #T_6571cbde_5e63_11e8_94ed_6c4008b1f526row7_col2 {
#             background-color:   ;
#         }    #T_6571cbde_5e63_11e8_94ed_6c4008b1f526row7_col3 {
#             background-color:   ;
#         }</style>
# <table id="T_6571cbde_5e63_11e8_94ed_6c4008b1f526" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >petal width (cm)</th>
#         <th class="col_heading level0 col1" >sepal width (cm)</th>
#         <th class="col_heading level0 col2" >petal length (cm)</th>
#         <th class="col_heading level0 col3" >sepal length (cm)</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_6571cbde_5e63_11e8_94ed_6c4008b1f526level0_row0" class="row_heading level0 row0" >count</th>
#         <td id="T_6571cbde_5e63_11e8_94ed_6c4008b1f526row0_col0" class="data row0 col0" >150</td>
#         <td id="T_6571cbde_5e63_11e8_94ed_6c4008b1f526row0_col1" class="data row0 col1" >150</td>
#         <td id="T_6571cbde_5e63_11e8_94ed_6c4008b1f526row0_col2" class="data row0 col2" >150</td>
#         <td id="T_6571cbde_5e63_11e8_94ed_6c4008b1f526row0_col3" class="data row0 col3" >150</td>
#     </tr>    <tr>
#         <th id="T_6571cbde_5e63_11e8_94ed_6c4008b1f526level0_row1" class="row_heading level0 row1" >mean</th>
#         <td id="T_6571cbde_5e63_11e8_94ed_6c4008b1f526row1_col0" class="data row1 col0" >1.19867</td>
#         <td id="T_6571cbde_5e63_11e8_94ed_6c4008b1f526row1_col1" class="data row1 col1" >3.054</td>
#         <td id="T_6571cbde_5e63_11e8_94ed_6c4008b1f526row1_col2" class="data row1 col2" >3.75867</td>
#         <td id="T_6571cbde_5e63_11e8_94ed_6c4008b1f526row1_col3" class="data row1 col3" >5.84333</td>
#     </tr>    <tr>
#         <th id="T_6571cbde_5e63_11e8_94ed_6c4008b1f526level0_row2" class="row_heading level0 row2" >std</th>
#         <td id="T_6571cbde_5e63_11e8_94ed_6c4008b1f526row2_col0" class="data row2 col0" >0.763161</td>
#         <td id="T_6571cbde_5e63_11e8_94ed_6c4008b1f526row2_col1" class="data row2 col1" >0.433594</td>
#         <td id="T_6571cbde_5e63_11e8_94ed_6c4008b1f526row2_col2" class="data row2 col2" >1.76442</td>
#         <td id="T_6571cbde_5e63_11e8_94ed_6c4008b1f526row2_col3" class="data row2 col3" >0.828066</td>
#     </tr>    <tr>
#         <th id="T_6571cbde_5e63_11e8_94ed_6c4008b1f526level0_row3" class="row_heading level0 row3" >min</th>
#         <td id="T_6571cbde_5e63_11e8_94ed_6c4008b1f526row3_col0" class="data row3 col0" >0.1</td>
#         <td id="T_6571cbde_5e63_11e8_94ed_6c4008b1f526row3_col1" class="data row3 col1" >2</td>
#         <td id="T_6571cbde_5e63_11e8_94ed_6c4008b1f526row3_col2" class="data row3 col2" >1</td>
#         <td id="T_6571cbde_5e63_11e8_94ed_6c4008b1f526row3_col3" class="data row3 col3" >4.3</td>
#     </tr>    <tr>
#         <th id="T_6571cbde_5e63_11e8_94ed_6c4008b1f526level0_row4" class="row_heading level0 row4" >25%</th>
#         <td id="T_6571cbde_5e63_11e8_94ed_6c4008b1f526row4_col0" class="data row4 col0" >0.3</td>
#         <td id="T_6571cbde_5e63_11e8_94ed_6c4008b1f526row4_col1" class="data row4 col1" >2.8</td>
#         <td id="T_6571cbde_5e63_11e8_94ed_6c4008b1f526row4_col2" class="data row4 col2" >1.6</td>
#         <td id="T_6571cbde_5e63_11e8_94ed_6c4008b1f526row4_col3" class="data row4 col3" >5.1</td>
#     </tr>    <tr>
#         <th id="T_6571cbde_5e63_11e8_94ed_6c4008b1f526level0_row5" class="row_heading level0 row5" >50%</th>
#         <td id="T_6571cbde_5e63_11e8_94ed_6c4008b1f526row5_col0" class="data row5 col0" >1.3</td>
#         <td id="T_6571cbde_5e63_11e8_94ed_6c4008b1f526row5_col1" class="data row5 col1" >3</td>
#         <td id="T_6571cbde_5e63_11e8_94ed_6c4008b1f526row5_col2" class="data row5 col2" >4.35</td>
#         <td id="T_6571cbde_5e63_11e8_94ed_6c4008b1f526row5_col3" class="data row5 col3" >5.8</td>
#     </tr>    <tr>
#         <th id="T_6571cbde_5e63_11e8_94ed_6c4008b1f526level0_row6" class="row_heading level0 row6" >75%</th>
#         <td id="T_6571cbde_5e63_11e8_94ed_6c4008b1f526row6_col0" class="data row6 col0" >1.8</td>
#         <td id="T_6571cbde_5e63_11e8_94ed_6c4008b1f526row6_col1" class="data row6 col1" >3.3</td>
#         <td id="T_6571cbde_5e63_11e8_94ed_6c4008b1f526row6_col2" class="data row6 col2" >5.1</td>
#         <td id="T_6571cbde_5e63_11e8_94ed_6c4008b1f526row6_col3" class="data row6 col3" >6.4</td>
#     </tr>    <tr>
#         <th id="T_6571cbde_5e63_11e8_94ed_6c4008b1f526level0_row7" class="row_heading level0 row7" >max</th>
#         <td id="T_6571cbde_5e63_11e8_94ed_6c4008b1f526row7_col0" class="data row7 col0" >2.5</td>
#         <td id="T_6571cbde_5e63_11e8_94ed_6c4008b1f526row7_col1" class="data row7 col1" >4.4</td>
#         <td id="T_6571cbde_5e63_11e8_94ed_6c4008b1f526row7_col2" class="data row7 col2" >6.9</td>
#         <td id="T_6571cbde_5e63_11e8_94ed_6c4008b1f526row7_col3" class="data row7 col3" >7.9</td>
#     </tr></tbody>
# </table>

# %%
# Missing Values in each column
fun_missing_value(df_iris)
# Out:
# <style  type="text/css" >
#     #T_65854f4c_5e63_11e8_bbce_6c4008b1f526row0_col0 {
#             background-color:   ;
#         }    #T_65854f4c_5e63_11e8_bbce_6c4008b1f526row0_col1 {
#             background-color:  lightgreen;
#         }    #T_65854f4c_5e63_11e8_bbce_6c4008b1f526row0_col2 {
#             background-color:  lightgreen;
#         }    #T_65854f4c_5e63_11e8_bbce_6c4008b1f526row1_col0 {
#             background-color:   ;
#         }    #T_65854f4c_5e63_11e8_bbce_6c4008b1f526row1_col1 {
#             background-color:  lightgreen;
#         }    #T_65854f4c_5e63_11e8_bbce_6c4008b1f526row1_col2 {
#             background-color:  lightgreen;
#         }    #T_65854f4c_5e63_11e8_bbce_6c4008b1f526row2_col0 {
#             background-color:   ;
#         }    #T_65854f4c_5e63_11e8_bbce_6c4008b1f526row2_col1 {
#             background-color:  lightgreen;
#         }    #T_65854f4c_5e63_11e8_bbce_6c4008b1f526row2_col2 {
#             background-color:  lightgreen;
#         }    #T_65854f4c_5e63_11e8_bbce_6c4008b1f526row3_col0 {
#             background-color:   ;
#         }    #T_65854f4c_5e63_11e8_bbce_6c4008b1f526row3_col1 {
#             background-color:  lightgreen;
#         }    #T_65854f4c_5e63_11e8_bbce_6c4008b1f526row3_col2 {
#             background-color:  lightgreen;
#         }</style>
# <table id="T_65854f4c_5e63_11e8_bbce_6c4008b1f526" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >column</th>
#         <th class="col_heading level0 col1" >missing_number</th>
#         <th class="col_heading level0 col2" >pct_missing</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_65854f4c_5e63_11e8_bbce_6c4008b1f526level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_65854f4c_5e63_11e8_bbce_6c4008b1f526row0_col0" class="data row0 col0" >sepal length (cm)</td>
#         <td id="T_65854f4c_5e63_11e8_bbce_6c4008b1f526row0_col1" class="data row0 col1" >0</td>
#         <td id="T_65854f4c_5e63_11e8_bbce_6c4008b1f526row0_col2" class="data row0 col2" >0</td>
#     </tr>    <tr>
#         <th id="T_65854f4c_5e63_11e8_bbce_6c4008b1f526level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_65854f4c_5e63_11e8_bbce_6c4008b1f526row1_col0" class="data row1 col0" >sepal width (cm)</td>
#         <td id="T_65854f4c_5e63_11e8_bbce_6c4008b1f526row1_col1" class="data row1 col1" >0</td>
#         <td id="T_65854f4c_5e63_11e8_bbce_6c4008b1f526row1_col2" class="data row1 col2" >0</td>
#     </tr>    <tr>
#         <th id="T_65854f4c_5e63_11e8_bbce_6c4008b1f526level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_65854f4c_5e63_11e8_bbce_6c4008b1f526row2_col0" class="data row2 col0" >petal length (cm)</td>
#         <td id="T_65854f4c_5e63_11e8_bbce_6c4008b1f526row2_col1" class="data row2 col1" >0</td>
#         <td id="T_65854f4c_5e63_11e8_bbce_6c4008b1f526row2_col2" class="data row2 col2" >0</td>
#     </tr>    <tr>
#         <th id="T_65854f4c_5e63_11e8_bbce_6c4008b1f526level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_65854f4c_5e63_11e8_bbce_6c4008b1f526row3_col0" class="data row3 col0" >petal width (cm)</td>
#         <td id="T_65854f4c_5e63_11e8_bbce_6c4008b1f526row3_col1" class="data row3 col1" >0</td>
#         <td id="T_65854f4c_5e63_11e8_bbce_6c4008b1f526row3_col2" class="data row3 col2" >0</td>
#     </tr></tbody>
# </table>

# %%
# Rows any missing values
fun_any_missing_row(df_iris)
# Out:
# Empty DataFrame
# Columns: [sepal length (cm), sepal width (cm), petal length (cm), petal width (cm)]
# Index: []

# %%
# 
fun_freq_column(iris_target['target'])
# Out:
# col_0       ptc_frequency
# target
# setosa             33.333
# versicolor         33.333
# virginica          33.333
